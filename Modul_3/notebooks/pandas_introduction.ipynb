# %%
import pandas as pd
x = pd.Series([34, 12, 23, 45])
print(x)
x.dtype
# Out:
# 0    34
# 1    12
# 2    23
# 3    45
# dtype: int64
# dtype('int64')

# %%
import pandas as pd
data = {'month': ['Jan', 'Feb', 'Mar', 'Apr'],
        'temp': [-5, 2, 3, 5],
         'below_zero': [True, False, False, False],
        'year': [2020, 2020, 2020, 2020]}
df = pd.DataFrame(data)
print(df)
# Out:
#   month  temp  below_zero  year
# 0   Jan    -5        True  2020
# 1   Feb     2       False  2020
# 2   Mar     3       False  2020
# 3   Apr     5       False  2020

# %% [markdown]
# *Skalenniveaus*
# - month: Intervallskala
# - temp: Intervallskala
# - below_zero: Nominalskala
# - year: Intervallskala

# %%
df.dtypes
# Out:
# month         object
# temp           int64
# below_zero      bool
# year           int64
# dtype: object

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
x = df['Total Renewals']
df[['Total Renewals', 'Total Checkouts']]
column_names = ['Total Renewals', 'Total Checkouts'] # auxiliary variable
subset = df[column_names]
print(x)
print(subset)
# Out:
# 0          0
# 1         22
# 2          0
# 3          0
# 4         11
#           ..
# 423443    13
# 423444    11
# 423445    58
# 423446     0
# 423447     0
# Name: Total Renewals, Length: 423448, dtype: int64
#         Total Renewals  Total Checkouts
# 0                    0                0
# 1                   22               31
# 2                    0                0
# 3                    0                0
# 4                   11              126
# ...                ...              ...
# 423443              13              291
# 423444              11               15
# 423445              58              208
# 423446               0               26
# 423447               0                0
#
# [423448 rows x 2 columns]

# %%
df['dummy_variable'] = 5

# %%
x = df['Total Renewals']
df['Total Renewals'] = 5
x
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 423443    5
# 423444    5
# 423445    5
# 423446    5
# 423447    5
# Name: Total Renewals, Length: 423448, dtype: int64

# %%
import numpy as np

df['is_adult'] = df['Patron Type Definition'] == 'ADULT'
df['log_renewals'] = np.log(df['Total Renewals'] + 1)

# %%
df['is_adult']
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 423443     True
# 423444     True
# 423445    False
# 423446     True
# 423447    False
# Name: is_adult, Length: 423448, dtype: bool

# %%
df['log_renewals']
# Out:
# 0         1.791759
# 1         1.791759
# 2         1.791759
# 3         1.791759
# 4         1.791759
#             ...
# 423443    1.791759
# 423444    1.791759
# 423445    1.791759
# 423446    1.791759
# 423447    1.791759
# Name: log_renewals, Length: 423448, dtype: float64

# %%
df["Circulation Active Year"]=pd.to_numeric ( df['Circulation Active Year'], errors='coerce')
df['Circulation Active Year']
# Out:
# 0            NaN
# 1         2016.0
# 2            NaN
# 3            NaN
# 4         2016.0
#            ...
# 423443    2015.0
# 423444    2016.0
# 423445    2016.0
# 423446    2015.0
# 423447       NaN
# Name: Circulation Active Year, Length: 423448, dtype: float64

# %%
df['Circulation Active Month'] =pd.to_datetime(
df['Circulation Active Month'],
errors='coerce',
format="%B"
)
df['Circulation Active Month']
# Out:
# 0               NaT
# 1        1900-04-01
# 2               NaT
# 3               NaT
# 4        1900-01-01
#             ...
# 423443   1900-03-01
# 423444   1900-07-01
# 423445   1900-07-01
# 423446   1900-04-01
# 423447          NaT
# Name: Circulation Active Month, Length: 423448, dtype: datetime64[ns]

# %%
df['Circulation Active Month'] =pd.to_datetime(
df['Circulation Active Month'],
errors='coerce',
format="%B"
)
df['Circulation Active Month']
# Out:
# 0         NaN
# 1         4.0
# 2         NaN
# 3         NaN
# 4         1.0
#          ...
# 423443    3.0
# 423444    7.0
# 423445    7.0
# 423446    4.0
# 423447    NaN
# Name: Circulation Active Month, Length: 423448, dtype: float64

# %%
df['Membership Duration'] = (
    df['Circulation Active Year'] - df['Year Patron Registered']
)*12 + df['Circulation Active Month']
# Out:
# 0           NaN
# 1          76.0
# 2           NaN
# 3           NaN
# 4         157.0
#           ...
# 423443     75.0
# 423444      7.0
# 423445     31.0
# 423446    148.0
# 423447      NaN
# Name: Membership Duration, Length: 423448, dtype: float64

# %%
df['Membership Duration'] = df['Membership Duration'].fillna(0)
df ['Membership Duration']
# Out:
# 0           0.0
# 1          76.0
# 2           0.0
# 3           0.0
# 4         157.0
#           ...
# 423443     75.0
# 423444      7.0
# 423445     31.0
# 423446    148.0
# 423447      0.0
# Name: Membership Duration, Length: 423448, dtype: float64

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.loc[df['Total Checkouts'] > 10000]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 851                    9                SPECIAL            18064
# 1963                   0                  ADULT            10521
# 3499                   0                  ADULT            12740
# 20042                  3                 SENIOR            16060
# 31315                  0                  ADULT            13784
# 39585                  0                  ADULT            11086
# 57239                  0                  ADULT            10906
# 86662                  3                 SENIOR            11748
# 117628                 0                  ADULT            11817
# 120604                 3                 SENIOR            10108
# 129341                 3                 SENIOR            12757
# 138351                 0                  ADULT            10809
# 145600                 3                 SENIOR            11871
# 146615                 0                  ADULT            24093
# 156806                 0                  ADULT            17308
# 163893                 3                 SENIOR            25223
# 176606                 0                  ADULT            10371
# 200204                 3                 SENIOR            18397
# 216300                 0                  ADULT            12950
# 222889                 3                 SENIOR            14502
# 227568                 3                 SENIOR            11147
# 231807                 3                 SENIOR            11896
# 237668                 0                  ADULT            15505
# 255021                 3                 SENIOR            11102
# 278408                 3                 SENIOR            11366
# 288655                 0                  ADULT            15598
# 290980                 0                  ADULT            12733
# 293371                 0                  ADULT            35907
# 294129                 0                  ADULT            10863
# 330536                 3                 SENIOR            10637
# 401287                 5                  STAFF            13362
#
#         Total Renewals          Age Range Home Library Code  \
# 851               2268     60 to 64 years                 X
# 1963               621     60 to 64 years                 X
# 3499              2209     45 to 54 years                C2
# 20042               66     65 to 74 years                C2
# 31315               74     60 to 64 years                M4
# 39585             1083     35 to 44 years                C2
      z
#
#        Notice Preference Definition  Provided Email Address  \
# 851                           phone                   False
# 1963                          phone                   False
# 3499                          email                    True
# 20042                         print                   False
# 31315                         email                    True
# 39585                         phone                   False
# 57239                         email                    True
# 86662                         email                    True
# 117628                        email                    True
# 120604                        phone                   False
# 129341                        phone                   False
# 138351                        email                    True
# 145600                        email                    True
# 146615                        phone                    True
# 156806                        email                    True
# 163893                        phone                   False
# 176606                        email                    True
# 200204                        email                    True
# 216300                        email                    True
# 222889                        email                    True
# 227568                        print                   False
# 231807                        email                    True
# 237668                        phone                   False
# 255021                        email                    True
# 278408                        email                    True
# 288655                        phone                   False
# 290980                        email                    True
# 293371                        phone                   False
# 294129                        phone                   False
# 330536                        phone                   False
# 401287                        email                    True
#
#         Year Patron Registered  Outside of County  Supervisor District
# 851                       2003              False                  NaN
# 1963                      2003              False                  6.0
# 3499                      2003              False                  3.0
# 20042                     2003              False                  3.0
# 31315                     2003              False                 11.0
# 39585                     2003              False                  3.0
# 57239                     2003              False                  8.0
# 86662                     2003              False                  5.0
# 117628                    2003              False                  4.0
# 120604                    2003              False                  6.0
# 129341                    2004              False                  NaN
# 138351                    2010              False                  4.0
# 145600                    2003              False                  7.0
# 146615                    2003              False                  4.0
# 156806                    2003              False                  6.0
# 163893                    2006              False                  9.0
# 176606                    2003              False                  4.0
# 200204                    2005              False                  NaN
# 216300                    2003              False                  4.0
# 222889                    2006              False                  8.0
# 227568                    2003              False                  NaN
# 231807                    2003              False                  8.0
# 237668                    2004              False                  6.0
# 255021                    2003              False                  NaN
# 278408                    2003              False                  8.0
# 288655                    2003              False                 11.0
# 290980                    2003              False                  8.0
# 293371                    2003              False                  NaN
# 294129                    2003              False                  6.0
# 330536                    2003              False                  3.0
# 401287                    2004               True                  NaN

# %%
row_filter = df['Total Checkouts'] > 10000
df.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 851                    9                SPECIAL            18064
# 1963                   0                  ADULT            10521
# 3499                   0                  ADULT            12740
# 20042                  3                 SENIOR            16060
# 31315                  0                  ADULT            13784
# 39585                  0                  ADULT            11086
# 57239                  0                  ADULT            10906
# 86662                  3                 SENIOR            11748
# 117628                 0                  ADULT            11817
# 120604                 3                 SENIOR            10108
# 129341                 3                 SENIOR            12757
# 138351                 0                  ADULT            10809
# 145600                 3                 SENIOR            11871
# 146615                 0                  ADULT            24093
# 156806                 0                  ADULT            17308
# 163893                 3                 SENIOR            25223
# 176606                 0                  ADULT            10371
# 200204                 3                 SENIOR            18397
# 216300                 0                  ADULT            12950
# 222889                 3                 SENIOR            14502
# 227568                 3                 SENIOR            11147
# 231807                 3                 SENIOR            11896
# 237668                 0                  ADULT            15505
# 255021                 3                 SENIOR            11102
# 278408                 3                 SENIOR            11366
# 288655                 0                  ADULT            15598
# 290980                 0                  ADULT            12733
# 293371                 0                  ADULT            35907
# 294129                 0                  ADULT            10863
# 330536                 3                 SENIOR            10637
# 401287                 5                  STAFF            13362
#
#         Total Renewals          Age Range Home Library Code  \
# 851               2268     60 to 64 years                 X
# 1963               621     60 to 64 years                 X
# 3499              2209     45 to 54 years                C2
# 20042               66     65 to 74 years                C2
# 31315               74     60 to 64 years                M4
# 39585             1083     35 to 44 years                C2
# 57239             1421     45 to 54 years                P1
# 86662              963     65 to 74 years                 X
# 117628            2859     45 to 54 years                S7
# 120604              59     65 to 74 years                 X
# 129341             500     65 to 74 years                R3
# 138351              24     20 to 24 years                S7
# 145600              50     65 to 74 years                M4
# 146615             383     45 to 54 years                 X
# 156806             257     60 to 64 years                 X
# 163893             448     65 to 74 years                 X
# 176606            1345     55 to 59 years                S7
# 200204               6     65 to 74 years                 X
# 216300            1548     60 to 64 years                O7
# 222889            3517     65 to 74 years                E7
# 227568             123     65 to 74 years                M6
# 231807            1408     65 to 74 years                E7
# 237668             294     60 to 64 years                 X
# 255021            2652     65 to 74 years                 X
# 278408              62     65 to 74 years                 X
# 288655             228     55 to 59 years                 X
# 290980              60     45 to 54 years                 X
# 293371             116     35 to 44 years                V3
# 294129              57     45 to 54 years                M6
# 330536             148  75 years and over                C2
# 401287            1926       0 to 9 years                 X
#
#                    Home Library Definition Circulation Active Month  \
# 851                           Main Library                     July
# 1963                          Main Library                     July
# 3499                             Chinatown                     July
# 20042                            Chinatown                     July
# 31315                               Merced                     June
# 39585                            Chinatown                     July
# 57239                                 Park                     July
# 86662                         Main Library                     July
# 117628                              Sunset                     July
# 120604                        Main Library                 November
# 129341                            Richmond                     July
# 138351                              Sunset                     July
# 145600                              Merced                     July
# 146615                        Main Library                     July
# 156806                        Main Library                     July
# 163893                        Main Library                     July
# 176606                              Sunset                     July
# 200204                        Main Library                     July
# 216300                              Ortega                     July
# 222889  Eureka Valley/Harvey Milk Memorial                     July
# 227568                             Mission                     July
# 231807  Eureka Valley/Harvey Milk Memorial                     July
# 237668                        Main Library                     July
# 255021                        Main Library                     July
# 278408                        Main Library                     July
# 288655                        Main Library                     July
# 290980                        Main Library                     July
# 293371                   Visitacion Valley                     July
# 294129                             Mission                     July
# 330536                           Chinatown                  January
# 401287                        Main Library                     July
#
#        Circulation Active Year Notice Preference Code  \
# 851                       2016                      p
# 1963                      2016                      p
# 3499                      2016                      z
# 20042                     2016                      a
# 31315                     2016                      z
# 39585                     2016                      p
# 57239                     2016                      z
# 86662                     2016                      z
# 117628                    2016                      z
# 120604                    2013                      p
# 129341                    2016                      p
# 138351                    2016                      z
# 145600                    2016                      z
# 146615                    2016                      p
# 156806                    2016                      z
# 163893                    2016                      p
# 176606                    2016                      z
# 200204                    2016                      z
# 216300                    2016                      z
# 222889                    2016                      z
# 227568                    2016                      a
# 231807                    2016                      z
# 237668                    2016                      p
# 255021                    2016                      z
# 278408                    2016                      z
# 288655                    2016                      p
# 290980                    2016                      z
# 293371                    2016                      p
# 294129                    2016                      p
# 330536                    2015                      p
# 401287                    2016                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 851                           phone                   False
# 1963                          phone                   False
# 3499                          email                    True
# 20042                         print                   False
# 31315                         email                    True
# 39585                         phone                   False
# 57239                         email                    True
# 86662                         email                    True
# 117628                        email                    True
# 120604                        phone                   False
# 129341                        phone                   False
# 138351                        email                    True
# 145600                        email                    True
# 146615                        phone                    True
# 156806                        email                    True
# 163893                        phone                   False
# 176606                        email                    True
# 200204                        email                    True
# 216300                        email                    True
# 222889                        email                    True
# 227568                        print                   False
# 231807                        email                    True
# 237668                        phone                   False
# 255021                        email                    True
# 278408                        email                    True
# 288655                        phone                   False
# 290980                        email                    True
# 293371                        phone                   False
# 294129                        phone                   False
# 330536                        phone                   False
# 401287                        email                    True
#
#         Year Patron Registered  Outside of County  Supervisor District
# 851                       2003              False                  NaN
# 1963                      2003              False                  6.0
# 3499                      2003              False                  3.0
# 20042                     2003              False                  3.0
# 31315                     2003              False                 11.0
# 39585                     2003              False                  3.0
# 57239                     2003              False                  8.0
# 86662                     2003              False                  5.0
# 117628                    2003              False                  4.0
# 120604                    2003              False                  6.0
# 129341                    2004              False                  NaN
# 138351                    2010              False                  4.0
# 145600                    2003              False                  7.0
# 146615                    2003              False                  4.0
# 156806                    2003              False                  6.0
# 163893                    2006              False                  9.0
# 176606                    2003              False                  4.0
# 200204                    2005              False                  NaN
# 216300                    2003              False                  4.0
# 222889                    2006              False                  8.0
# 227568                    2003              False                  NaN
# 231807                    2003              False                  8.0
# 237668                    2004              False                  6.0
# 255021                    2003              False                  NaN
# 278408                    2003              False                  8.0
# 288655                    2003              False                 11.0
# 290980                    2003              False                  8.0
# 293371                    2003              False                  NaN
# 294129                    2003              False                  6.0
# 330536                    2003              False                  3.0
# 401287                    2004               True                  NaN

# %%
row_filter = (df['Patron Type Definition'] == 'SENIOR') & (df['Notice Preference Definition'] == 'email')
df.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 5                      3                 SENIOR                0
# 62                     3                 SENIOR              193
# 176                    3                 SENIOR                7
# 260                    3                 SENIOR              341
# 294                    3                 SENIOR               67
# ...                  ...                    ...              ...
# 423359                 3                 SENIOR                4
# 423388                 3                 SENIOR               25
# 423403                 3                 SENIOR              458
# 423405                 3                 SENIOR              280
# 423431                 3                 SENIOR                0
#
#         Total Renewals          Age Range Home Library Code  \
# 5                    0     65 to 74 years                C2
# 62                  90     65 to 74 years                A5
# 176                  8     65 to 74 years                 X
# 260                212     65 to 74 years                P1
# 294                 26  75 years and over                P5
# ...                ...                ...               ...
# 423359               0  75 years and over                W4
# 423388              34  75 years and over                 X
# 423403             129  75 years and over                E9
# 423405              27  75 years and over                 X
# 423431               0  75 years and over                 X
#
#        Home Library Definition Circulation Active Month  \
# 5                    Chinatown                     None
# 62                        Anza                     July
# 176               Main Library                    April
# 260                       Park                     July
# 294                    Portola                     July
# ...                        ...                      ...
# 423359        Western Addition                      May
# 423388            Main Library                      May
# 423403               Excelsior                     June
# 423405            Main Library                     July
# 423431            Main Library                     None
#
#        Circulation Active Year Notice Preference Code  \
# 5                         None                      z
# 62                        2016                      z
# 176                       2014                      z
# 260                       2016                      z
# 294                       2016                      z
# ...                        ...                    ...
# 423359                    2013                      z
# 423388                    2016                      z
# 423403                    2016                      z
# 423405                    2016                      z
# 423431                    None                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 5                             email                    True
# 62                            email                    True
# 176                           email                    True
# 260                           email                    True
# 294                           email                    True
# ...                             ...                     ...
# 423359                        email                    True
# 423388                        email                    True
# 423403                        email                    True
# 423405                        email                    True
# 423431                        email                    True
#
#         Year Patron Registered  Outside of County  Supervisor District
# 5                         2015               True                  NaN
# 62                        2007              False                  1.0
# 176                       2012               True                  NaN
# 260                       2003              False                  5.0
# 294                       2009              False                  9.0
# ...                        ...                ...                  ...
# 423359                    2012              False                  5.0
# 423388                    2015               True                  NaN
# 423403                    2003               True                  NaN
# 423405                    2003              False                  9.0
# 423431                    2012              False                  6.0
#
# [25220 rows x 15 columns]

# %%
filter1 = (df['Total Checkouts'] >= 20) & (df['Total Checkouts'] <= 80)
filter2 =  df['Total Checkouts'].between(20, 80)
all(filter1 == filter2)
# Out:
# True

# %% [markdown]
# ## Aufgabe 2.6

# %%
kinder_unter_10 = (df['Age Range'] == '0 to 9 years')
df.loc[kinder_unter_10]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 287                    1               JUVENILE                0
# 289                    1               JUVENILE               20
# 291                    1               JUVENILE               53
# 292                    1               JUVENILE                1
# 295                    1               JUVENILE                0
# ...                  ...                    ...              ...
# 423434                 1               JUVENILE               10
# 423437                 1               JUVENILE                0
# 423439                 1               JUVENILE                0
# 423445                 5                  STAFF              208
# 423447                 1               JUVENILE                0
#
#         Total Renewals     Age Range Home Library Code  \
# 287                  0  0 to 9 years                M6
# 289                  0  0 to 9 years                E9
# 291                 31  0 to 9 years                A5
# 292                  0  0 to 9 years                O7
# 295                  0  0 to 9 years                A5
# ...                ...           ...               ...
# 423434               0  0 to 9 years                V3
# 423437               0  0 to 9 years                W4
# 423439               0  0 to 9 years                N4
# 423445              58  0 to 9 years                B4
# 423447               0  0 to 9 years                E7
#
#                    Home Library Definition Circulation Active Month  \
# 287                                Mission                     None
# 289                              Excelsior                     July
# 291                                   Anza                     June
# 292                                 Ortega                     June
# 295                                   Anza                     None
# ...                                    ...                      ...
# 423434                   Visitacion Valley                September
# 423437                    Western Addition                     None
# 423439              Noe Valley/Sally Brunn                     None
# 423445                      Bernal Heights                     July
# 423447  Eureka Valley/Harvey Milk Memorial                     None
#
#        Circulation Active Year Notice Preference Code  \
# 287                       None                      p
# 289                       2016                      z
# 291                       2013                      z
# 292                       2014                      z
# 295                       None                      z
# ...                        ...                    ...
# 423434                    2015                      p
# 423437                    None                      z
# 423439                    None                      z
# 423445                    2016                      z
# 423447                    None                      a
#
#        Notice Preference Definition  Provided Email Address  \
# 287                           phone                   False
# 289                           email                    True
# 291                           email                    True
# 292                           email                    True
# 295                           email                    True
# ...                             ...                     ...
# 423434                        phone                   False
# 423437                        email                    True
# 423439                        email                    True
# 423445                        email                    True
# 423447                        print                   False
#
#         Year Patron Registered  Outside of County  Supervisor District
# 287                       2014              False                  6.0
# 289                       2016              False                 11.0
# 291                       2012              False                  1.0
# 292                       2014              False                  5.0
# 295                       2016              False                  8.0
# ...                        ...                ...                  ...
# 423434                    2012              False                 10.0
# 423437                    2015              False                  5.0
# 423439                    2015              False                  8.0
# 423445                    2014              False                  9.0
# 423447                    2015              False                  8.0
#
# [38242 rows x 15 columns]

# %%
print(len(df[kinder_unter_10]))
# Out:
# 38242

# %%
mehr_als_2000_Ausleihen = (df['Total Checkouts'] > 2000)
df.loc[mehr_als_2000_Ausleihen]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 6                      0                  ADULT             3002
# 102                    0                  ADULT             2630
# 193                    0                  ADULT             8984
# 225                    0                  ADULT             2041
# 493                    0                  ADULT             3072
# ...                  ...                    ...              ...
# 423270                 1               JUVENILE             3331
# 423346                 3                 SENIOR             2893
# 423416                 2            YOUNG ADULT             2428
# 423422                 2            YOUNG ADULT             3914
# 423423                 0                  ADULT             2592
#
#         Total Renewals          Age Range Home Library Code  \
# 6                 1689     25 to 34 years                P5
# 102               1501     45 to 54 years                M4
# 193                310     60 to 64 years                C2
# 225               1097     60 to 64 years                N6
# 493               1391     45 to 54 years                 X
# ...                ...                ...               ...
# 423270             502     10 to 19 years                O7
# 423346              54  75 years and over                C2
# 423416            1280     10 to 19 years                P3
# 423422             359     10 to 19 years                P5
# 423423             487     10 to 19 years                I5
#
#        Home Library Definition Circulation Active Month  \
# 6                      Portola                     July
# 102                     Merced                     July
# 193                  Chinatown                     July
# 225                North Beach                     July
# 493               Main Library                     July
# ...                        ...                      ...
# 423270                  Ortega                     July
# 423346               Chinatown                     July
# 423416                Parkside                    April
# 423422                 Portola                     July
# 423423               Ingleside                  January
#
#        Circulation Active Year Notice Preference Code  \
# 6                         2016                      p
# 102                       2016                      p
# 193                       2016                      z
# 225                       2016                      z
# 493                       2016                      z
# ...                        ...                    ...
# 423270                    2016                      p
# 423346                    2016                      a
# 423416                    2016                      z
# 423422                    2016                      p
# 423423                    2016                      p
#
#        Notice Preference Definition  Provided Email Address  \
# 6                             phone                    True
# 102                           phone                   False
# 193                           email                    True
# 225                           email                    True
# 493                           email                    True
# ...                             ...                     ...
# 423270                        phone                   False
# 423346                        print                   False
# 423416                        email                    True
# 423422                        phone                   False
# 423423                        phone                   False
#
#         Year Patron Registered  Outside of County  Supervisor District
# 6                         2004              False                  9.0
# 102                       2003               True                  NaN
# 193                       2003               True                  NaN
# 225                       2003              False                  3.0
# 493                       2003              False                  2.0
# ...                        ...                ...                  ...
# 423270                    2006              False                  4.0
# 423346                    2003              False                  4.0
# 423416                    2003              False                  7.0
# 423422                    2010              False                  9.0
# 423423                    2003              False                 10.0
#
# [4804 rows x 15 columns]

# %%
print(len(df[mehr_als_2000_Ausleihen]))
# Out:
# 4804

# %%
df['Supervisor District'].isin([1, 2, 3]).sum()
# Out:
# 70091

# %%
df['Circulation Active Year'] = pd.to_numeric(
   df['Circulation Active Year'], errors='coerce'
)

# %%
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'],
    errors='coerce',
    format="%B"
)

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month

df['Membership Duration'] = (
   df['Circulation Active Year'] - df['Year Patron Registered']
)*12 + df['Circulation Active Month']
df['Membership Duration'] = df['Membership Duration'].fillna(0)

# %%
print(len(df[df['Membership Duration'] == 0])/len(df))
# Out:
# 0.16035971358938997

# %%
df = pd.read_csv("../data/Library_Usage.csv", na_values="None")
df['Circulation Active Year']
# Out:
# 0            NaN
# 1         2016.0
# 2            NaN
# 3            NaN
# 4         2016.0
#            ...
# 423443    2015.0
# 423444    2016.0
# 423445    2016.0
# 423446    2015.0
# 423447       NaN
# Name: Circulation Active Year, Length: 423448, dtype: float64

# %%
df[df['Age Range'].isna()]
df[df['Age Range'].notna()]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# 2                    0  45 to 54 years                P1
# 3                    0  25 to 34 years                 X
# 4                   11  45 to 54 years                M2
# ...                ...             ...               ...
# 423443              13  10 to 19 years                P5
# 423444              11  60 to 64 years                M8
# 423445              58    0 to 9 years                B4
# 423446               0  10 to 19 years                M6
# 423447               0    0 to 9 years                E7
#
#                    Home Library Definition Circulation Active Month  \
# 0                                     Park                      NaN
# 1                                   Sunset                    April
# 2                                     Park                      NaN
# 3                             Main Library                      NaN
# 4                                   Marina                  January
# ...                                    ...                      ...
# 423443                             Portola                    March
# 423444                         Mission Bay                     July
# 423445                      Bernal Heights                     July
# 423446                             Mission                    April
# 423447  Eureka Valley/Harvey Milk Memorial                      NaN
#
#         Circulation Active Year Notice Preference Code  \
# 0                           NaN                      z
# 1                        2016.0                      z
# 2                           NaN                      a
# 3                           NaN                      z
# 4                        2016.0                      z
# ...                         ...                    ...
# 423443                   2015.0                      p
# 423444                   2016.0                      z
# 423445                   2016.0                      z
# 423446                   2015.0                      z
# 423447                      NaN                      a
#
#        Notice Preference Definition  Provided Email Address  \
# 0                             email                    True
# 1                             email                    True
# 2                             print                   False
# 3                             email                    True
# 4                             email                    True
# ...                             ...                     ...
# 423443                        phone                   False
# 423444                        email                    True
# 423445                        email                    True
# 423446                        email                    True
# 423447                        print                   False
#
#         Year Patron Registered  Outside of County  Supervisor District
# 0                         2014              False                  5.0
# 1                         2010              False                  4.0
# 2                         2016               True                  NaN
# 3                         2015              False                  3.0
# 4                         2003              False                  2.0
# ...                        ...                ...                  ...
# 423443                    2009              False                  9.0
# 423444                    2016              False                  6.0
# 423445                    2014              False                  9.0
# 423446                    2003              False                  9.0
# 423447                    2015              False                  8.0
#
# [423233 rows x 15 columns]

# %% [markdown]
# # Aufgabe 2.8

# %%
import pandas as pd
df = pd.read_csv('../data/Library_Usage.csv')

# %%
len(df) - df.count()
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          215
# Home Library Code                   40
# Home Library Definition              0
# Circulation Active Month             0
# Circulation Active Year              0
# Notice Preference Code               0
# Notice Preference Definition         0
# Provided Email Address               0
# Year Patron Registered               0
# Outside of County                    0
# Supervisor District             110310
# dtype: int64

# %%
df.isna().sum()
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          215
# Home Library Code                   40
# Home Library Definition              0
# Circulation Active Month             0
# Circulation Active Year              0
# Notice Preference Code               0
# Notice Preference Definition         0
# Provided Email Address               0
# Year Patron Registered               0
# Outside of County                    0
# Supervisor District             110310
# dtype: int64

# %%
df_clean = df.dropna()
df_clean.isna().sum()
# Out:
# Patron Type Code                0
# Patron Type Definition          0
# Total Checkouts                 0
# Total Renewals                  0
# Age Range                       0
# Home Library Code               0
# Home Library Definition         0
# Circulation Active Month        0
# Circulation Active Year         0
# Notice Preference Code          0
# Notice Preference Definition    0
# Provided Email Address          0
# Year Patron Registered          0
# Outside of County               0
# Supervisor District             0
# dtype: int64

# %%
len(df) - len(df_clean)
# Out:
# 110480

# %%
df_clean.to_csv('../data/Library_Usage_Clean.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.head(100)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  0                  ADULT                0               0
# 1                  0                  ADULT               31              22
# 2                  0                  ADULT                0               0
# 3                  0                  ADULT                0               0
# 4                  0                  ADULT              126              11
# ..               ...                    ...              ...             ...
# 95                 0                  ADULT                0               0
# 96                 0                  ADULT               11               0
# 97                 0                  ADULT              160              44
# 98                 0                  ADULT               11               3
# 99                 0                  ADULT               40               0
#
#          Age Range Home Library Code Home Library Definition  \
# 0   20 to 24 years                P1                    Park
# 1   25 to 34 years                S7                  Sunset
# 2   45 to 54 years                P1                    Park
# 3   25 to 34 years                 X            Main Library
# 4   45 to 54 years                M2                  Marina
# ..             ...               ...                     ...
# 95  35 to 44 years                 X            Main Library
# 96  20 to 24 years                 X            Main Library
# 97  25 to 34 years                R3                Richmond
# 98  35 to 44 years                M2                  Marina
# 99  45 to 54 years                O7                  Ortega
#
#    Circulation Active Month Circulation Active Year Notice Preference Code  \
# 0                      None                    None                      z
# 1                     April                    2016                      z
# 2                      None                    None                      a
# 3                      None                    None                      z
# 4                   January                    2016                      z
# ..                      ...                     ...                    ...
# 95                     None                    None                      z
# 96                September                    2015                      z
# 97                      May                    2015                      z
# 98                    March                    2014                      z
# 99                    April                    2015                      p
#
#    Notice Preference Definition  Provided Email Address  \
# 0                         email                    True
# 1                         email                    True
# 2                         print                   False
# 3                         email                    True
# 4                         email                    True
# ..                          ...                     ...
# 95                        email                    True
# 96                        email                    True
# 97                        email                    True
# 98                        email                    True
# 99                        phone                    True
#
#     Year Patron Registered  Outside of County  Supervisor District
# 0                     2014              False                  5.0
# 1                     2010              False                  4.0
# 2                     2016               True                  NaN
# 3                     2015              False                  3.0
# 4                     2003              False                  2.0
# ..                     ...                ...                  ...
# 95                    2012              False                  1.0
# 96                    2015              False                  NaN
# 97                    2003              False                  1.0
# 98                    2003              False                  NaN
# 99                    2003              False                  4.0
#
# [100 rows x 15 columns]

# %%
df.tail(50)
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
#
# 423445                    2016                      z
# 423446                    2015                      z
# 423447                    None                      a
#
#        Notice Preference Definition  Provided Email Address  \
# 423398                        email                    True
# 423399                        email                    True
# 423400                        email                    True
# 423401                        print                   False
# 423402                        phone                    True
# 423403                        email                    True
# 423404                        print                   False
# 423405                        email                    True
# 423406                        print                    True
# 423407                        phone                   False
# 423408                        email                    True
# 423409                        email                    True
# 423410                        email                    True
# 423411                        print                   False
# 423412                        email                    True
# 423413                        email                    True
# 423414                        phone                   False
# 423415                        email                    True
# 423416                        email                    True
# 423417                        email                    True
# 423418                        phone                   False
# 423419                        phone                   False
# 423420                        email                    True
# 423421                        phone                   False
# 423422                        phone                   False
# 423423                        phone                   False
# 423424                        phone                   False
# 423425                        email                    True
# 423426                        email                    True
# 423427                        email                    True
# 423428                        phone                   False
# 423429                        email                    True
# 423430                        email                    True
# 423431                        email                    True
# 423432                        print                   False
# 423433                        email                    True
# 423434                        phone                   False
# 423435                        email                    True
# 423436                        email                    True
# 423437                        email                    True
# 423438                        email                    True
# 423439                        email                    True
# 423440                        phone                   False
# 423441                        phone                   False
# 423442                        email                    True
# 423443                        phone                   False
# 423444                        email                    True
# 423445                        email                    True
# 423446                        email                    True
# 423447                        print                   False
#
#         Year Patron Registered  Outside of County  Supervisor District
# 423398                    2015              False                  5.0
# 423399                    2014              False                  4.0
# 423400                    2011              False                  NaN
# 423401                    2003              False                  NaN
# 423402                    2011               True                  NaN
# 423403                    2003               True                  NaN
# 423404                    2012              False                  8.0
# 423405                    2003              False                  9.0
# 423406                    2003               True                  NaN
# 423407                    2009              False                 10.0
# 423408                    2014              False                  3.0
# 423409                    2009              False                  4.0
# 423410                    2010              False                  6.0
# 423411                    2012              False                  7.0
# 423412                    2010              False                  9.0
# 423413                    2007              False                  3.0
# 423414                    2009              False                  NaN
# 423415                    2014              False                  2.0
# 423416                    2003              False                  7.0
# 423417                    2015              False                  6.0
# 423418                    2014              False                  1.0
# 423419                    2013              False                  7.0
# 423420                    2015              False                  1.0
# 423421                    2003              False                  NaN
# 423422                    2010              False                  9.0
# 423423                    2003              False                 10.0
# 423424                    2014              False                 10.0
# 423425                    2013              False                  4.0
# 423426                    2009              False                  9.0
# 423427                    2015              False                  3.0
# 423428                    2003              False                  5.0
# 423429                    2015              False                  8.0
# 423430                    2010              False                  6.0
# 423431                    2012              False                  6.0
# 423432                    2013               True                  NaN
# 423433                    2014              False                  6.0
# 423434                    2012              False                 10.0
# 423435                    2015              False                 10.0
# 423436                    2016               True                  NaN
# 423437                    2015              False                  5.0
# 423438                    2015               True                  NaN
# 423439                    2015              False                  8.0
# 423440                    2011               True                  NaN
# 423441                    2012              False                  3.0
# 423442                    2003              False                  7.0
# 423443                    2009              False                  9.0
# 423444                    2016              False                  6.0
# 423445                    2014              False                  9.0
# 423446                    2003              False                  9.0
# 423447                    2015              False                  8.0

# %%
df.describe(include='all')
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# count      423448.000000                 423448    423448.000000
# unique               NaN                     18              NaN
# top                  NaN                  ADULT              NaN
# freq                 NaN                 272251              NaN
# mean            1.036765                    NaN       161.982097
# std             4.188198                    NaN       453.703678
# min             0.000000                    NaN         0.000000
# 25%             0.000000                    NaN         2.000000
# 50%             0.000000                    NaN        19.000000
# 75%             1.000000                    NaN       113.000000
# max           104.000000                    NaN     35907.000000
#
#         Total Renewals       Age Range Home Library Code  \
# count    423448.000000          423233            423408
# unique             NaN              10                79
# top                NaN  25 to 34 years                 X
# freq               NaN           91083            124814
# mean         59.657327             NaN               NaN
# std         225.009917             NaN               NaN
# min           0.000000             NaN               NaN
# 25%           0.000000             NaN               NaN
# 50%           2.000000             NaN               NaN
# 75%          27.000000             NaN               NaN
# max        8965.000000             NaN               NaN
#
#        Home Library Definition Circulation Active Month  \
# count                   423448                   423448
# unique                      35                       13
# top               Main Library                     July
# freq                    124814                    91566
# mean                       NaN                      NaN
# std                        NaN                      NaN
# min                        NaN                      NaN
# 25%                        NaN                      NaN
# 50%                        NaN                      NaN
# 75%                        NaN                      NaN
# max                        NaN                      NaN
#
#        Circulation Active Year Notice Preference Code  \
# count                   423448                 423448
# unique                      15                      4
# top                       2016                      z
# freq                    147901                 323937
# mean                       NaN                    NaN
# std                        NaN                    NaN
# min                        NaN                    NaN
# 25%                        NaN                    NaN
# 50%                        NaN                    NaN
# 75%                        NaN                    NaN
# max                        NaN                    NaN
#
#        Notice Preference Definition Provided Email Address  \
# count                        423448                 423448
# unique                            4                      2
# top                           email                   True
# freq                         323937                 336420
# mean                            NaN                    NaN
# std                             NaN                    NaN
# min                             NaN                    NaN
# 25%                             NaN                    NaN
# 50%                             NaN                    NaN
# 75%                             NaN                    NaN
# max                             NaN                    NaN
#
#         Year Patron Registered Outside of County  Supervisor District
# count            423448.000000            423448        313138.000000
# unique                     NaN                 2                  NaN
# top                        NaN             False                  NaN
# freq                       NaN            359628                  NaN
# mean               2010.348917               NaN             6.288240
# std                   4.357374               NaN             3.123634
# min                2003.000000               NaN             1.000000
# 25%                2007.000000               NaN             4.000000
# 50%                2012.000000               NaN             6.000000
# 75%                2014.000000               NaN             9.000000
# max                2016.000000               NaN            11.000000

# %%
print(df['Total Renewals'].min())
# Out:
# 0

# %%
df['Total Renewals'].between(100, 200).sum()
# Out:
# 21739

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Patron Type Code                  int64
# Patron Type Definition           object
# Total Checkouts                   int64
# Total Renewals                    int64
# Age Range                        object
# Home Library Code                object
# Home Library Definition          object
# Circulation Active Month         object
# Circulation Active Year          object
# Notice Preference Code           object
# Notice Preference Definition     object
# Provided Email Address             bool
# Year Patron Registered            int64
# Outside of County                  bool
# Supervisor District             float64
# dtype: object

# %%
df.shape
# Out:
# (423448, 15)
